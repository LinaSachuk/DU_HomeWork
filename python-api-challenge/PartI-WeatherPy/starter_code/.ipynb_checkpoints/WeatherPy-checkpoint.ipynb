# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Testing citipy modul
city1 = citipy.nearest_city(22.99, 120.21)
print(city1)
print(city1.city_name)
print(city1.country_code)
# print(weather_api_key)
# Out:
# <citipy.citipy.City object at 0x1a2646a910>
# tainan
# tw

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)


# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        

# Print the city count to confirm sufficient count
print(len(cities))
print(cities[0:10])
# Out:
# 614
# ['castro', 'kununurra', 'pangnirtung', 'hermanus', 'bluff', 'butaritari', 'new norfolk', 'yuzhnyy', 'ambunti', 'taoudenni']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

# Build query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
city_data = []
cloudiness = []
country = []
date = []
humidity =[]
lat = []
lng = []
max_temp = []
wind_speed =[]
count = 0
count_error = 0


# Loop through the list of cities and perform a request for data on each
for city in cities:
    
    response = requests.get(query_url + city).json()
    try:
#         pprint(response)
#         print('==============')
        
        city_data_v = (response['name'])
        country_v = (response['sys']['country'])
        cloudiness_v = (response['clouds']['all'])
        date_v = (response['dt'])
        humidity_v = (response['main']['humidity'])
        lat_v = (response['coord']['lat'])
        lng_v =(response['coord']['lon'])
        max_temp_v = (response['main']['temp_max'])
        wind_speed_v = (response['wind']['speed'])
        
        city_data.append(city_data_v)
        country.append(country_v)
        cloudiness.append(cloudiness_v)
        date.append(date_v)
        humidity.append(humidity_v)
        lat.append(lat_v)
        lng.append(lng_v)
        max_temp.append(max_temp_v)
        wind_speed.append(wind_speed_v)
        count +=1
        print(f"City number: {count},  city name: {city_data_v}")
        
        
    except (KeyError, IndexError):
        count_error +=1
        print(f"Missing field/result... skipping. {count_error}") 
        
print(f"Total results :{count} cities")        
print(f"Missing field/result:{count_error} errors") 
        
# print(f"city: {city_data}" )
# print(f"country: {country}")
# print(f"cloudiness: {cloudiness}")
# print(f"date: {date}")
# print(f"humidity: {humidity}")
# print(f"lat: {lat}")
# print(f"lng: {lng}")
# print(f"max_temp: {max_temp}")
# print(f"wind_speed: {wind_speed}")
# Out:
# City number: 1,  city name: Castro
# City number: 2,  city name: Kununurra
# City number: 3,  city name: Pangnirtung
# City number: 4,  city name: Hermanus
# City number: 5,  city name: Bluff
# City number: 6,  city name: Butaritari
# City number: 7,  city name: New Norfolk
# City number: 8,  city name: Yuzhnyy
# City number: 9,  city name: Ambunti
# City number: 10,  city name: Taoudenni
# City number: 11,  city name: Qaanaaq
# City number: 12,  city name: Tiksi
# City number: 13,  city name: Kemin
# City number: 14,  city name: Port Hardy
# City number: 15,  city name: Dzhebariki-Khaya
# City number: 16,  city name: Carnarvon
# City number: 17,  city name: Khovd
# City number: 18,  city name: Avarua
# City number: 19,  city name: Norman Wells
# City number: 20,  city name: Port Alfred
# City number: 21,  city name: Písek
# Missing field/result... skipping. 1
# City number: 22,  city name: Saldanha
# City number: 23,  city name: Quryq
# Missing field/result... skipping. 2
# City number: 24,  city name: Balikpapan
# City number: 25,  city name: Thinadhoo
# City number: 26,  city name: Yellowknife
# City number: 27,  city name: Saint Anthony
# Missing field/result... skipping. 3
# City number: 28,  city name: Ponta do Sol
# Missing field/result... skipping. 4
# City number: 29,  city name: Khatanga
# City number: 30,  city name: Cherskiy
# City number: 31,  city name: Ushuaia
# City number: 32,  city name: Rosarito
# City number: 33,  city name: Sambava
# City number: 34,  city name: Puerto Ayora
# City number: 35,  city name: Thompson
# Missing field/result... skipping. 5
# City number: 36,  city name: Aklavik
# City number: 37,  city name: Pilar
# City number: 38,  city name: Kattivākkam
# Missing field/result... skipping. 6
# City number: 39,  city name: Malino
# Missing field/result... skipping. 7
# City number: 40,  city name: Puri
# City number: 41,  city name: Sühbaatar
# City number: 42,  city name: Sabha
# City number: 43,  city name: Busselton
# City number: 44,  city name: Bengkulu
# City number: 45,  city name: Lata
# City number: 46,  city name: Pevek
# Missing field/result... skipping. 8
# City number: 47,  city name: Jamestown
# City number: 48,  city name: Nikolskoye
# City number: 49,  city name: San Quintín
# City number: 50,  city name: La Macarena
# City number: 51,  city name: Faya
# City number: 52,  city name: Stornoway
# City number: 53,  city name: Shenzhen
# City number: 54,  city name: Khani
# City number: 55,  city name: Mnogovershinnyy
# City number: 56,  city name: Pangody
# Missing field/result... skipping. 9
# City number: 57,  city name: Talnakh
# City number: 58,  city name: Mataura
# City number: 59,  city name: Ribeira Grande
# City number: 60,  city name: Buala
# City number: 61,  city name: Sampit
# City number: 62,  city name: Ponta Delgada
# City number: 63,  city name: Pisco
# City number: 64,  city name: Albany
# Missing field/result... skipping. 10
# City number: 65,  city name: Punta Arenas
# City number: 66,  city name: Saint Paul Harbor
# City number: 67,  city name: Bethel
# City number: 68,  city name: Złocieniec
# City number: 69,  city name: Abéché
# City number: 70,  city name: Vaini
# City number: 71,  city name: Kaitangata
# City number: 72,  city name: Tessalit
# City number: 73,  city name: Kaeo
# City number: 74,  city name: Atuona
# City number: 75,  city name: Quatre Cocos
# City number: 76,  city name: Rikitea
# City number: 77,  city name: Maragogi
# City number: 78,  city name: Carlisle
# City number: 79,  city name: Kapaa
# Missing field/result... skipping. 11
# City number: 80,  city name: Tilichiki
# City number: 81,  city name: East London
# City number: 82,  city name: Lebu
# City number: 83,  city name: Upernavik
# City number: 84,  city name: Gunjur
# City number: 85,  city name: Saint-Philippe
# City number: 86,  city name: Ilulissat
# City number: 87,  city name: Hamilton
# Missing field/result... skipping. 12
# City number: 88,  city name: Omboué
# City number: 89,  city name: Quimperlé
# City number: 90,  city name: Lokosovo
# City number: 91,  city name: Okha
# City number: 92,  city name: Geraldton
# City number: 93,  city name: Bambous Virieux
# City number: 94,  city name: Contamana
# City number: 95,  city name: Tungor
# Missing field/result... skipping. 13
# City number: 96,  city name: Rio Grande
# City number: 97,  city name: Lakes Entrance
# City number: 98,  city name: Rokiškis
# City number: 99,  city name: Villa Carlos Paz
# City number: 100,  city name: Port Lincoln
# City number: 101,  city name: Provideniya
# City number: 102,  city name: Caranavi
# City number: 103,  city name: São Paulo de Olivença
# City number: 104,  city name: Mahébourg
# Missing field/result... skipping. 14
# City number: 105,  city name: Tura
# City number: 106,  city name: Yenagoa
# City number: 107,  city name: Ancud
# City number: 108,  city name: Kalispell
# City number: 109,  city name: Muros
# City number: 110,  city name: Airai
# City number: 111,  city name: Kushiro
# City number: 112,  city name: Sulina
# City number: 113,  city name: Dunedin
# City number: 114,  city name: Ambovombe
# City number: 115,  city name: Hemnesberget
# City number: 116,  city name: Vieste
# City number: 117,  city name: Nebbi
# City number: 118,  city name: Tuktoyaktuk
# City number: 119,  city name: Sisimiut
# City number: 120,  city name: Samarai
# City number: 121,  city name: Caravelas
# City number: 122,  city name: La Ronge
# City number: 123,  city name: Puerto del Rosario
# City number: 124,  city name: Biloela
# City number: 125,  city name: Esperance
# City number: 126,  city name: Micheweni
# City number: 127,  city name: Siddipet
# City number: 128,  city name: Alofi
# City number: 129,  city name: Barrow
# City number: 130,  city name: Zabid
# City number: 131,  city name: Port Elizabeth
# Missing field/result... skipping. 15
# City number: 132,  city name: Lorengau
# City number: 133,  city name: Lüderitz
# City number: 134,  city name: Dikson
# City number: 135,  city name: Örnsköldsvik
# City number: 136,  city name: Hobart
# City number: 137,  city name: Soyo
# City number: 138,  city name: Halifax
# City number: 139,  city name: Zhirnovsk
# City number: 140,  city name: Prince Rupert
# City number: 141,  city name: Longyearbyen
# City number: 142,  city name: Rawson
# Missing field/result... skipping. 16
# City number: 143,  city name: Warrington
# City number: 144,  city name: Batemans Bay
# City number: 145,  city name: Padang
# City number: 146,  city name: Zabaykal'sk
# City number: 147,  city name: Cape Town
# Missing field/result... skipping. 17
# City number: 148,  city name: San Patricio
# City number: 149,  city name: Bonthe
# City number: 150,  city name: Teacapan
# City number: 151,  city name: Antón Lizardo
# City number: 152,  city name: Coquimbo
# Missing field/result... skipping. 18
# City number: 153,  city name: Mar del Plata
# City number: 154,  city name: Benguela
# City number: 155,  city name: Iracoubo
# Missing field/result... skipping. 19
# City number: 156,  city name: Maniitsoq
# City number: 157,  city name: Chunoyar
# Missing field/result... skipping. 20
# City number: 158,  city name: Coyhaique
# City number: 159,  city name: Kashirskoye
# City number: 160,  city name: Hilo
# City number: 161,  city name: Tres Arroyos
# City number: 162,  city name: Hengshui
# City number: 163,  city name: Laas
# City number: 164,  city name: Acheng
# City number: 165,  city name: Weiser
# City number: 166,  city name: Salalah
# City number: 167,  city name: Imbituba
# City number: 168,  city name: Ossora
# City number: 169,  city name: Tasiilaq
# City number: 170,  city name: South Lake Tahoe
# Missing field/result... skipping. 21
# City number: 171,  city name: Hauterive
# City number: 172,  city name: Umm Kaddadah
# City number: 173,  city name: Chipinge
# City number: 174,  city name: Faanui
# City number: 175,  city name: Kuril'sk
# City number: 176,  city name: Husavik
# City number: 177,  city name: Praia da Vitória
# City number: 178,  city name: Sorrento
# City number: 179,  city name: Isangel
# City number: 180,  city name: Magadan
# City number: 181,  city name: Kinsale
# City number: 182,  city name: Barra Patuca
# City number: 183,  city name: Fethiye
# City number: 184,  city name: Mayo
# City number: 185,  city name: Ialibu
# City number: 186,  city name: Baijiantan
# City number: 187,  city name: Kismayo
# City number: 188,  city name: Yar-Sale
# City number: 189,  city name: San Lazaro
# City number: 190,  city name: Kupang
# City number: 191,  city name: Ayan
# City number: 192,  city name: Collierville
# City number: 193,  city name: Itarema
# City number: 194,  city name: Kabinda
# City number: 195,  city name: Cândido Mota
# City number: 196,  city name: Shaunavon
# City number: 197,  city name: Bintulu
# Missing field/result... skipping. 22
# City number: 198,  city name: ‘Ewa Beach
# Missing field/result... skipping. 23
# City number: 199,  city name: Fortuna
# City number: 200,  city name: Morondava
# City number: 201,  city name: Verkhoyansk
# City number: 202,  city name: Leshukonskoye
# City number: 203,  city name: Narsaq
# City number: 204,  city name: Egvekinot
# City number: 205,  city name: Kahului
# City number: 206,  city name: Den Helder
# City number: 207,  city name: Alta Floresta
# City number: 208,  city name: Vaitape
# City number: 209,  city name: Houma
# City number: 210,  city name: Hong Kong
# City number: 211,  city name: Rocha
# City number: 212,  city name: Pimentel
# City number: 213,  city name: Kjøllefjord
# City number: 214,  city name: Carutapera
# City number: 215,  city name: Gölköy
# City number: 216,  city name: Saint-Louis
# City number: 217,  city name: Mandalgovi
# City number: 218,  city name: Flinders
# Missing field/result... skipping. 24
# City number: 219,  city name: Lavrentiya
# City number: 220,  city name: Sitka
# Missing field/result... skipping. 25
# City number: 221,  city name: George Town
# City number: 222,  city name: Edd
# City number: 223,  city name: Dingle
# Missing field/result... skipping. 26
# City number: 224,  city name: Olafsvik
# City number: 225,  city name: Tanout
# City number: 226,  city name: Santa Fe
# City number: 227,  city name: São Francisco
# City number: 228,  city name: Nizhniy Odes
# City number: 229,  city name: Paramonga
# City number: 230,  city name: Coruripe
# City number: 231,  city name: Berlevåg
# City number: 232,  city name: College
# City number: 233,  city name: Severobaykal'sk
# City number: 234,  city name: Longview
# Missing field/result... skipping. 27
# City number: 235,  city name: Douglas
# City number: 236,  city name: Mortka
# Missing field/result... skipping. 28
# City number: 237,  city name: Kolhāpur
# City number: 238,  city name: Severo-Kuril'sk
# Missing field/result... skipping. 29
# City number: 239,  city name: Novikovo
# City number: 240,  city name: Berdigestyakh
# City number: 241,  city name: Ballina
# City number: 242,  city name: Suez
# City number: 243,  city name: Orshanka
# City number: 244,  city name: Yulara
# City number: 245,  city name: Mastic Beach
# City number: 246,  city name: Arraial do Cabo
# City number: 247,  city name: São Gabriel da Cachoeira
# City number: 248,  city name: Palu
# City number: 249,  city name: Tirano
# City number: 250,  city name: Souillac
# Missing field/result... skipping. 30
# City number: 251,  city name: Cidreira
# Missing field/result... skipping. 31
# City number: 252,  city name: Sorong
# City number: 253,  city name: Diamantino
# Missing field/result... skipping. 32
# City number: 254,  city name: Bredasdorp
# City number: 255,  city name: Tongren
# City number: 256,  city name: Poronaysk
# City number: 257,  city name: Nālūt
# City number: 258,  city name: Hobyo
# City number: 259,  city name: Yangi Marg`ilon
# City number: 260,  city name: Teahupoo
# City number: 261,  city name: Kamakwie
# City number: 262,  city name: Paamiut
# City number: 263,  city name: Bonavista
# City number: 264,  city name: Mathbaria
# City number: 265,  city name: Burnie
# City number: 266,  city name: Warner Robins
# City number: 267,  city name: Sinnamary
# Missing field/result... skipping. 33
# City number: 268,  city name: Dali
# City number: 269,  city name: Constitución
# City number: 270,  city name: Peterhead
# City number: 271,  city name: Acapulco de Juárez
# City number: 272,  city name: Leningradskiy
# City number: 273,  city name: Carauari
# City number: 274,  city name: Araouane
# City number: 275,  city name: Kelso
# Missing field/result... skipping. 34
# City number: 276,  city name: Jijiga
# Missing field/result... skipping. 35
# City number: 277,  city name: Mount Gambier
# City number: 278,  city name: Torbay
# City number: 279,  city name: San Carlos
# City number: 280,  city name: Plettenberg Bay
# City number: 281,  city name: Chumikan
# City number: 282,  city name: Lagoa
# City number: 283,  city name: Banda Aceh
# City number: 284,  city name: Waupun
# City number: 285,  city name: Hede
# City number: 286,  city name: Cabo San Lucas
# City number: 287,  city name: Bull Savanna
# City number: 288,  city name: Bilibino
# City number: 289,  city name: Seoul
# City number: 290,  city name: Leh
# City number: 291,  city name: Loutrós
# City number: 292,  city name: Clyde River
# City number: 293,  city name: Abū Zabad
# City number: 294,  city name: La Palma
# City number: 295,  city name: Alta
# City number: 296,  city name: Chui
# City number: 297,  city name: Ochamchira
# City number: 298,  city name: Āsosa
# City number: 299,  city name: Gombe
# City number: 300,  city name: Paita
# City number: 301,  city name: Chokurdakh
# City number: 302,  city name: Zhigansk
# Missing field/result... skipping. 36
# City number: 303,  city name: Klaksvík
# City number: 304,  city name: Mocuba
# City number: 305,  city name: Vyshchetarasivka
# City number: 306,  city name: Northam
# City number: 307,  city name: Necochea
# City number: 308,  city name: Traverse City
# Missing field/result... skipping. 37
# City number: 309,  city name: Hithadhoo
# City number: 310,  city name: Buenos Aires
# City number: 311,  city name: Pierre
# City number: 312,  city name: Bowen
# City number: 313,  city name: Nelson Bay
# City number: 314,  city name: San Cristobal
# City number: 315,  city name: Port Blair
# City number: 316,  city name: Pizarro
# City number: 317,  city name: Rabo de Peixe
# City number: 318,  city name: Bay Roberts
# City number: 319,  city name: Māngrol
# City number: 320,  city name: Broken Hill
# City number: 321,  city name: Senanga
# Missing field/result... skipping. 38
# City number: 322,  city name: San Jerónimo
# City number: 323,  city name: Xinqing
# City number: 324,  city name: Guerrero Negro
# City number: 325,  city name: Yumen
# City number: 326,  city name: Revelstoke
# City number: 327,  city name: Saskylakh
# City number: 328,  city name: Yei
# Missing field/result... skipping. 39
# City number: 329,  city name: Fortaleza
# City number: 330,  city name: Shahrud
# City number: 331,  city name: Norton
# City number: 332,  city name: Narganá
# City number: 333,  city name: Yangambi
# City number: 334,  city name: Cockburn Town
# City number: 335,  city name: São João da Barra
# City number: 336,  city name: Vanavara
# City number: 337,  city name: Nanortalik
# City number: 338,  city name: Bathsheba
# City number: 339,  city name: Broome
# City number: 340,  city name: Banjar
# City number: 341,  city name: Arman'
# City number: 342,  city name: Atar
# Missing field/result... skipping. 40
# City number: 343,  city name: Juegang
# City number: 344,  city name: Abu Samrah
# City number: 345,  city name: Codrington
# City number: 346,  city name: Umba
# City number: 347,  city name: Evans
# Missing field/result... skipping. 41
# City number: 348,  city name: Iqaluit
# City number: 349,  city name: Takoradze
# City number: 350,  city name: Nur-Sultan
# City number: 351,  city name: Poum
# City number: 352,  city name: Nyurba
# City number: 353,  city name: Bako
# City number: 354,  city name: Richards Bay
# City number: 355,  city name: Novobureyskiy
# City number: 356,  city name: Namatanai
# City number: 357,  city name: Auchel
# City number: 358,  city name: Sur
# City number: 359,  city name: Katherine
# City number: 360,  city name: Ferme-Neuve
# City number: 361,  city name: Ankpa
# Missing field/result... skipping. 42
# City number: 362,  city name: The Valley
# City number: 363,  city name: Rio Branco do Sul
# City number: 364,  city name: Strezhevoy
# City number: 365,  city name: Noumea
# City number: 366,  city name: Grand Gaube
# City number: 367,  city name: Ixtapa
# City number: 368,  city name: Huejuquilla el Alto
# City number: 369,  city name: Khasan
# City number: 370,  city name: Saint George
# City number: 371,  city name: Denpasar
# City number: 372,  city name: Abu Dhabi
# City number: 373,  city name: Touros
# City number: 374,  city name: Port-Gentil
# City number: 375,  city name: Bandarbeyla
# City number: 376,  city name: Kropotkin
# City number: 377,  city name: Russell
# Missing field/result... skipping. 43
# Missing field/result... skipping. 44
# City number: 378,  city name: Robertson
# City number: 379,  city name: Gimli
# City number: 380,  city name: Aksarka
# City number: 381,  city name: Karratha
# Missing field/result... skipping. 45
# City number: 382,  city name: Oksovskiy
# City number: 383,  city name: Halayhay
# City number: 384,  city name: Mariehamn
# Missing field/result... skipping. 46
# City number: 385,  city name: Kuala Lipis
# City number: 386,  city name: Katsuura
# City number: 387,  city name: Goma
# City number: 388,  city name: Don Luan
# City number: 389,  city name: Amahai
# City number: 390,  city name: Nizhniy Baskunchak
# City number: 391,  city name: Kamaishi
# City number: 392,  city name: Sosnovo-Ozerskoye
# City number: 393,  city name: Mezhdurechensk
# City number: 394,  city name: Vardø
# City number: 395,  city name: Spasskoye
# City number: 396,  city name: Tautira
# City number: 397,  city name: Härnösand
# City number: 398,  city name: Abalak
# City number: 399,  city name: Sterling
# City number: 400,  city name: Haines Junction
# City number: 401,  city name: Musoma
# City number: 402,  city name: Umluj
# City number: 403,  city name: Barobo
# Missing field/result... skipping. 47
# City number: 404,  city name: Tancheng
# City number: 405,  city name: Rome
# City number: 406,  city name: Vestmannaeyjar
# City number: 407,  city name: Ayagoz
# City number: 408,  city name: Neepawa
# Missing field/result... skipping. 48
# Missing field/result... skipping. 49
# City number: 409,  city name: Havre-St-Pierre
# City number: 410,  city name: Mattru
# City number: 411,  city name: Naryan-Mar
# City number: 412,  city name: Porbandar
# City number: 413,  city name: Sonsón
# City number: 414,  city name: Chicama
# Missing field/result... skipping. 50
# City number: 415,  city name: Batagay-Alyta
# City number: 416,  city name: Kavieng
# City number: 417,  city name: Buraidah
# City number: 418,  city name: Forestville
# City number: 419,  city name: Virginia Beach
# City number: 420,  city name: Kruisfontein
# City number: 421,  city name: Rybinsk
# City number: 422,  city name: Adoni
# City number: 423,  city name: Rio Verde de Mato Grosso
# City number: 424,  city name: Guapí
# City number: 425,  city name: Kavaratti
# City number: 426,  city name: Champerico
# City number: 427,  city name: Kichera
# City number: 428,  city name: Gobabis
# Missing field/result... skipping. 51
# Missing field/result... skipping. 52
# City number: 429,  city name: Nouadhibou
# City number: 430,  city name: Beyneu
# City number: 431,  city name: Vila Franca do Campo
# City number: 432,  city name: Moussoro
# City number: 433,  city name: Ust'-Uda
# City number: 434,  city name: Cap Malheureux
# City number: 435,  city name: Honningsvåg
# City number: 436,  city name: South Kazakhstan Region
# City number: 437,  city name: Kapit
# City number: 438,  city name: Anadyr
# City number: 439,  city name: Freeport
# City number: 440,  city name: Søgne
# City number: 441,  city name: Tuatapere
# City number: 442,  city name: Todos Santos
# City number: 443,  city name: Bridgend
# City number: 444,  city name: Macenta
# City number: 445,  city name: Waingapu
# City number: 446,  city name: Hasaki
# City number: 447,  city name: Cayenne
# City number: 448,  city name: São José da Coroa Grande
# City number: 449,  city name: Te Anau
# City number: 450,  city name: Monroe
# City number: 451,  city name: Vangaindrano
# City number: 452,  city name: Jaru
# City number: 453,  city name: Ahipara
# City number: 454,  city name: Gizo Government Station
# City number: 455,  city name: Baykit
# City number: 456,  city name: Usinsk
# City number: 457,  city name: Sabang
# Missing field/result... skipping. 53
# City number: 458,  city name: Songyang
# City number: 459,  city name: Sola
# City number: 460,  city name: Aykhal
# City number: 461,  city name: Murmashi
# City number: 462,  city name: Moerai
# City number: 463,  city name: Port Hawkesbury
# City number: 464,  city name: Kuching
# City number: 465,  city name: Kiboga
# City number: 466,  city name: Lorvão
# City number: 467,  city name: Yüksekova
# City number: 468,  city name: Lae
# City number: 469,  city name: Monterey
# City number: 470,  city name: Santa Rosa
# City number: 471,  city name: Chifeng
# City number: 472,  city name: Winnemucca
# City number: 473,  city name: Arinos
# City number: 474,  city name: Margate
# City number: 475,  city name: Belmonte
# City number: 476,  city name: Darhan
# City number: 477,  city name: Brae
# City number: 478,  city name: Folldal
# City number: 479,  city name: Tairua
# City number: 480,  city name: Nuuk
# City number: 481,  city name: Baringo
# City number: 482,  city name: Pokhara
# City number: 483,  city name: Laï
# City number: 484,  city name: Pitkyaranta
# Missing field/result... skipping. 54
# City number: 485,  city name: Sioux Lookout
# City number: 486,  city name: Ust-Nera
# City number: 487,  city name: Martapura
# City number: 488,  city name: Mizdah
# City number: 489,  city name: Hare Bay
# City number: 490,  city name: Gazalkent
# City number: 491,  city name: Bāfq
# City number: 492,  city name: Vol'sk
# City number: 493,  city name: Aurora
# City number: 494,  city name: Flin Flon
# City number: 495,  city name: Wanxian
# City number: 496,  city name: Caconda
# City number: 497,  city name: Dawson Creek
# City number: 498,  city name: Huarmey
# City number: 499,  city name: Pirovskoye
# City number: 500,  city name: Maryville
# City number: 501,  city name: Evensk
# City number: 502,  city name: Hualmay
# City number: 503,  city name: Moyale
# City number: 504,  city name: Tommot
# City number: 505,  city name: Labuhan
# City number: 506,  city name: De Aar
# City number: 507,  city name: Kutum
# City number: 508,  city name: Moroni
# City number: 509,  city name: Oranjemund
# City number: 510,  city name: Ulaanbaatar
# City number: 511,  city name: Tigil'
# City number: 512,  city name: Bubaque
# City number: 513,  city name: Annau
# City number: 514,  city name: Sumkino
# City number: 515,  city name: Ketchikan
# City number: 516,  city name: Bilma
# City number: 517,  city name: Takaka
# City number: 518,  city name: Camabatela
# City number: 519,  city name: Honiara
# City number: 520,  city name: Bose
# City number: 521,  city name: Kortkeros
# City number: 522,  city name: Whitehorse
# City number: 523,  city name: Inhambane
# City number: 524,  city name: Iranshahr
# City number: 525,  city name: Inuvik
# City number: 526,  city name: Okhotsk
# City number: 527,  city name: Bela
# City number: 528,  city name: Redlands
# City number: 529,  city name: Gönen
# City number: 530,  city name: Pringsewu
# City number: 531,  city name: Mumbwa
# City number: 532,  city name: Steinheim
# City number: 533,  city name: General Roca
# City number: 534,  city name: Adrar
# City number: 535,  city name: Kholm
# City number: 536,  city name: Antofagasta
# Missing field/result... skipping. 55
# City number: 537,  city name: Vazhiny
# City number: 538,  city name: Puerto Peñasco
# City number: 539,  city name: Līsakovsk
# City number: 540,  city name: Qasigiannguit
# City number: 541,  city name: Moranbah
# City number: 542,  city name: Nemuro
# City number: 543,  city name: Pāveh
# City number: 544,  city name: Bagdarin
# City number: 545,  city name: Nador
# City number: 546,  city name: Concarneau
# City number: 547,  city name: Yagodnoye
# City number: 548,  city name: Omsukchan
# City number: 549,  city name: Moose Factory
# City number: 550,  city name: Daşoguz
# City number: 551,  city name: Veshenskaya
# City number: 552,  city name: Cururupu
# City number: 553,  city name: Deputatsky
# City number: 554,  city name: Wonthaggi
# Missing field/result... skipping. 56
# Missing field/result... skipping. 57
# City number: 555,  city name: Eureka
# City number: 556,  city name: Laela
# City number: 557,  city name: Bokovskaya
# Total results :557 cities
# Missing field/result:57 errors

# %%
print(f"city: {len(city_data)}" )
print(f"country: {len(country)}")
print(f"cloudiness: {len(cloudiness)}")
print(f"date: {len(date)}")
print(f"humidity: {len(humidity)}")
print(f"lat: {len(lat)}")
print(f"lng: {len(lng)}")
print(f"max_temp: {len(max_temp)}")
print(f"wind_speed: {len(wind_speed)}")
# Out:
# city: 557
# country: 557
# cloudiness: 557
# date: 557
# humidity: 557
# lat: 557
# lng: 557
# max_temp: 557
# wind_speed: 557

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "City": city_data,
    "Country" :  country,    
    "Cloudiness": cloudiness,
    "Date":  date,
    "Humidity" : humidity,  
    "Lat" : lat,
    "Lng": lng,
    "Max Temp" :  max_temp,
    "Wind Speed": wind_speed
}
weather_data = pd.DataFrame(weather_dict)
print(weather_data.count())
weather_data.head()
# Out:
# City          557
# Country       557
# Cloudiness    557
# Date          557
# Humidity      557
# Lat           557
# Lng           557
# Max Temp      557
# Wind Speed    557
# dtype: int64
#           City Country  Cloudiness        Date  Humidity    Lat     Lng  \
# 0       Castro      BR          69  1583130818        92 -24.79  -50.01
# 1    Kununurra      AU          75  1583130818        88 -15.77  128.73
# 2  Pangnirtung      CA           4  1583130818        69  66.15  -65.71
# 3     Hermanus      ZA           2  1583130818        81 -34.42   19.23
# 4        Bluff      NZ          34  1583130818        34 -46.60  168.33
#
#    Max Temp  Wind Speed
# 0     57.63        9.37
# 1     82.40       11.41
# 2    -25.35        0.43
# 3     73.00        5.99
# 4     75.99        8.01

# %%
import dash_bootstrap_components as dbc
# render dataframe as html
html = weather_data.to_html()
print(html)
weather_data.to_html('weather_data.html')
weather_data.to_html('weather_data.txt')
table = dbc.Table.from_dataframe(weather_data, striped=True, bordered=True, hover=True, responsive=True,)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-6aa1b24f40db> in <module>
# ----> 1 import dash_bootstrap_components as dbc
#       2 # render dataframe as html
#       3 html = weather_data.to_html()
#       4 print(html)
#       5 weather_data.to_html('weather_data.html')
#
# ModuleNotFoundError: No module named 'dash_bootstrap_components'

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data.to_csv('output.csv', encoding='utf-8', index=False)

# %%
weather_data.head()
# Out:
#           City Country  Cloudiness        Date  Humidity    Lat     Lng  \
# 0    Tuatapere      NZ          56  1580083741        60 -46.13  167.68
# 1        Taman      RU          40  1580083741        86  45.21   36.72
# 2  Yellowknife      CA          75  1580083741        84  62.46 -114.35
# 3         Hilo      US          75  1580083741        58  19.73 -155.09
# 4    Cape Town      ZA          75  1580083591        77 -33.93   18.42
#
#    Max Temp  Wind Speed
# 0     68.00        8.99
# 1     41.00        8.95
# 2      3.20        8.05
# 3     82.40       12.75
# 4     62.01        3.36

# %%
today_date = time.strftime("%x")
today_date
# Out:
# '01/26/20'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# OPTIONAL: Create a function to create Linear Regression plots

def linearRegrassionPlot(x_values, y_values, title, xlabel, ylabel, fileName):

        (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
        regress_values = x_values * slope + intercept

        line_eq = f'y = {str(round(slope,2))}x + {str(round(intercept,2))}'

        plt.scatter(x_values,y_values, marker="o", facecolors="b", edgecolors="r", alpha=0.55)
        plt.plot(x_values,regress_values,"r-")
        
        # Creating an extra space on the plot for the equation of the regression line
        plt.annotate(line_eq,(x_values.min() , y_values.max()+ 0.05 * y_values.max()),fontsize=14,color="red")

        # To change the size of your pie chart/figure
        fig = plt.gcf()
        fig.set_size_inches(8,5)

        # Creating a title, x label, and y label 
        plt.title(title, fontsize=18, color='purple', alpha=0.85)
        plt.xlabel(xlabel, fontsize=16)
        plt.ylabel(ylabel, fontsize=16)

        # Create x limits of our scatter plot 
        if x_values.max() > 0:
            plt.xlim(x_values.min() - np.absolute(0.05 * x_values.min()) - 5, x_values.max() + 0.05 * x_values.max() + 5)
        else:
            plt.xlim(x_values.min() - np.absolute(0.05 * x_values.min()) - 5, x_values.max() - 0.05 * x_values.max() + 5)

        # Create y limits of our scatter plot
        if y_values.max() > 0:
            plt.ylim(y_values.min() - np.absolute(0.05 * y_values.min()) - 5, y_values.max() + 0.10 * y_values.max() + 5)
        else:
            plt.ylim(y_values.min() - np.absolute(0.05 * y_values.min()) - 5, y_values.max() - 0.10 * y_values.max() + 5)

        print(f"The r-squared is: {rvalue}")
        print(f"The equation of the regression line is: {line_eq}")

        # Save the plotted figures as .pngs
        plt.savefig(fileName + '.png')

        plt.grid()
        plt.show()

# %%
# Latitude vs. Temperature Plot
linearRegrassionPlot(weather_data['Lat'], weather_data['Max Temp'], f'City Latitude vs. Max Temperature({today_date})', 'Latitude', 'Max Temperature', 'City Latitude vs. Max Temperature')
# Out:
# The r-squared is: -0.7780593969252194
# The equation of the regression line is: y = -0.71x + 64.36

# %% [markdown]
# Data Analysis:
# There is a a strong negative correlation : -0.78.
# The plot shows a relationship between two variables whereby they move in opposite directions. Variables 'Latitude' and 'Max Temperature' have a negative correlation (or are negatively correlated), as 'Latitude' increases in value, 'Max Temperature' will decrease; similarly, if 'Latitude' decreases in value, 'Max Temperature' will increase.
# The weather becomes significantly warmer as one approaches the equator. The northern hemisphere tends to be colder this time of the year than the southern hemisphere.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Latitude vs. Humidity Plot
linearRegrassionPlot(weather_data['Lat'], weather_data['Humidity'], f'City Latitude vs. Humidity ({today_date})', 'Latitude', 'Humidity', 'City Latitude vs. Humidity')
# Out:
# The r-squared is: 0.2339592909769523
# The equation of the regression line is: y = 0.14x + 72.33

# %% [markdown]
# Data Analysis:
# In the plot above, you can see that 'Latitude' and 'Humidity' have a weak positive correlation.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Latitude vs. Cloudiness Plot
linearRegrassionPlot(weather_data['Lat'], weather_data['Cloudiness'], f'City Latitude vs. Cloudiness ({today_date})', 'Latitude', 'Cloudiness', 'City Latitude vs. Cloudiness')
# Out:
# The r-squared is: 0.1796271703039652
# The equation of the regression line is: y = 0.2x + 53.21

# %% [markdown]
# Data Analysis: In the plot above, you can see that 'Latitude' and 'Cloudiness' have a weak positive correlation.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Latitude vs. Wind Speed Plot
linearRegrassionPlot(weather_data['Lat'], weather_data['Wind Speed'], f'City Latitude vs. Wind Speed ({today_date})', 'Latitude', 'Wind Speed', 'City Latitude vs. Wind Speed')
# Out:
# The r-squared is: -0.04961991944722433
# The equation of the regression line is: y = -0.01x + 8.1

# %% [markdown]
# Data Analysis: In the plot above, you can see that 'Latitude' and 'Wind Speed' have a weak positive correlation. Wind speed tends to generally be betweeen 0 and 20 mph regardless of latitude.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern Hemisphere DataFrames
northern_hemisphere = weather_data.loc[weather_data['Lat']>= 0]
print(northern_hemisphere.shape)
northern_hemisphere.head()
# Out:
# (369, 9)
#           City Country  Cloudiness        Date  Humidity    Lat     Lng  \
# 1        Taman      RU          40  1580083741        86  45.21   36.72
# 2  Yellowknife      CA          75  1580083741        84  62.46 -114.35
# 3         Hilo      US          75  1580083741        58  19.73 -155.09
# 5    Hong Kong      HK          40  1580083716        71  22.29  114.16
# 7        Erzin      TR           3  1580083742        86  36.96   36.20
#
#    Max Temp  Wind Speed
# 1      41.0        8.95
# 2       3.2        8.05
# 3      82.4       12.75
# 5      55.0       12.75
# 7      46.4        6.93

# %%
# Create Southern Hemisphere DataFrames
southern_hemisphere = weather_data.loc[weather_data['Lat'] < 0]
print(southern_hemisphere.shape)
southern_hemisphere.head()
# Out:
# (182, 9)
#              City Country  Cloudiness        Date  Humidity    Lat     Lng  \
# 0       Tuatapere      NZ          56  1580083741        60 -46.13  167.68
# 4       Cape Town      ZA          75  1580083591        77 -33.93   18.42
# 6          Faanui      PF          90  1580083742        72 -16.48 -151.75
# 10   Saint-Joseph      RE          75  1580083743        78 -21.37   55.62
# 11  Alice Springs      AU          12  1580083743        11 -23.70  133.88
#
#     Max Temp  Wind Speed
# 0      68.00        8.99
# 4      62.01        3.36
# 6      83.41        9.93
# 10     73.40        8.05
# 11     91.40       17.22

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression
linearRegrassionPlot(northern_hemisphere['Lat'], northern_hemisphere['Max Temp'], 'Northern Hemisphere - Max Temp vs. Latitude', 'Latitude', 'Max Temperature', 'Northern Hemisphere - Max Temp vs. Latitude')
# Out:
# The r-squared is: -0.8483674613042056
# The equation of the regression line is: y = -1.31x + 90.97

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression
linearRegrassionPlot(southern_hemisphere['Lat'], southern_hemisphere['Max Temp'], 'Southern Hemisphere - Max Temp vs. Latitude', 'Latitude', 'Max Temperature', 'Southern Hemisphere - Max Temp vs. Latitude')
# Out:
# The r-squared is: 0.421250636910282
# The equation of the regression line is: y = 0.3x + 80.7

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# Data Analysis for Northern and Southern hemispheres - Max Temp vs. Latitude: There is a strong negative correlation  : -0.76 in Northern hemisphere and a moderate correlation in Southern(but we also have a lot less cities in the Southern hemispheres for this dataset)

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
linearRegrassionPlot(northern_hemisphere['Lat'], northern_hemisphere['Humidity'], 'Northern Hemisphere - Humidity (%) vs. Latitude', 'Latitude', 'Humidity', 'Northern Hemisphere - Humidity (%) vs. Latitude')
# Out:
# The r-squared is: 0.39181212007061705
# The equation of the regression line is: y = 0.42x + 58.76

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
linearRegrassionPlot(southern_hemisphere['Lat'], southern_hemisphere['Humidity'], 'Southern Hemisphere - Humidity (%) vs. Latitude', 'Latitude', 'Humidity', 'Southern Hemisphere - Humidity (%) vs. Latitude')
# Out:
# The r-squared is: 0.44462602583795496
# The equation of the regression line is: y = 0.54x + 85.85

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# Data Analysis for Northern and Southern hemispheres - Humidity (%) vs. Latitude: There is a weak correlation for both hemispheres.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
linearRegrassionPlot(northern_hemisphere['Lat'], northern_hemisphere['Cloudiness'], 'Northern Hemisphere - Cloudiness (%) vs. Latitude', 'Latitude', 'Cloudiness', 'Northern Hemisphere - Cloudiness (%) vs. Latitude')
# Out:
# The r-squared is: 0.3088960614283116
# The equation of the regression line is: y = 0.59x + 34.19

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
linearRegrassionPlot(southern_hemisphere['Lat'], southern_hemisphere['Cloudiness'], 'Southern Hemisphere - Cloudiness (%) vs. Latitude', 'Latitude', 'Cloudiness', 'Southern Hemisphere - Cloudiness (%) vs. Latitude')
# Out:
# The r-squared is: 0.2473748250477238
# The equation of the regression line is: y = 0.67x + 69.72

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# Data Analysis for Northern and Southern hemispheres - Humidity (%) vs. Latitude: There are a weak negative and weak correlation for both hemispheres.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
linearRegrassionPlot(northern_hemisphere['Lat'], northern_hemisphere['Wind Speed'], 'Northern Hemisphere - Wind Speed (mph) vs. Latitude', 'Latitude', 'Wind Speed', 'Northern Hemisphere - Wind Speed (mph) vs. Latitude')
# Out:
# The r-squared is: 0.04229977600025659
# The equation of the regression line is: y = 0.01x + 7.4

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
linearRegrassionPlot(southern_hemisphere['Lat'], southern_hemisphere['Wind Speed'], 'Southern Hemisphere - Wind Speed (mph) vs. Latitude', 'Latitude', 'Wind Speed', 'Southern Hemisphere - Wind Speed (mph) vs. Latitude')
# Out:
# The r-squared is: -0.38614008674406447
# The equation of the regression line is: y = -0.17x + 4.37

# %%
# Out:
# The r-squared is: -0.322483077139538

# %% [markdown]
# Data Analysis for Northern and Southern hemispheres - Wind Speed vs. Latitude: There are a weak positive and weak negative correlations for both hemispheres.
